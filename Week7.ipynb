# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniel-Pereira3264/Machine-Learning-using-Python-Edge-Training/blob/main/week7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Feature selection using corelation method

# %%
import pandas as pd

# Assuming df is your dataframe with features and target
df = pd.read_csv('/content/FuelConsumptionCo2.csv')
df.head(2)
# Out:
#    MODELYEAR   MAKE MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION  \
# 0       2014  ACURA   ILX      COMPACT         2.0          4          AS5
# 1       2014  ACURA   ILX      COMPACT         2.4          4           M6
#
#   FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 0        Z                   9.9                  6.7                   8.5
# 1        Z                  11.2                  7.7                   9.6
#
#    FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                        33           196
# 1                        29           221

# %%
import pandas as pd

# Assuming df is your dataframe with features and target
# df = pd.read_csv('your_data.csv')

# Exclude object type columns
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns

numerical_columns=numerical_columns.drop('MODELYEAR')

# Compute the correlation matrix
corr_matrix = df[numerical_columns].corr()

# Assuming 'target' is the name of your target variable column
# Selecting features highly correlated with the target

target_correlation = corr_matrix['CO2EMISSIONS'].abs().sort_values(ascending=False)

target_correlation
# Out:
# CO2EMISSIONS                1.000000
# FUELCONSUMPTION_COMB_MPG    0.906394
# FUELCONSUMPTION_CITY        0.898039
# FUELCONSUMPTION_COMB        0.892129
# ENGINESIZE                  0.874154
# FUELCONSUMPTION_HWY         0.861748
# CYLINDERS                   0.849685
# Name: CO2EMISSIONS, dtype: float64

# %%
numerical_columns.drop('MODELYEAR')
# Out:
# Index(['ENGINESIZE', 'CYLINDERS', 'FUELCONSUMPTION_CITY',
#        'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
#        'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS'],
#       dtype='object')

# %% [markdown]
# # chi-square test

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Sample data (replace with your own data)
X = pd.DataFrame({
    'Feature1': [1, 0, 1, 0, 1],
    'Feature2': ['A', 'B', 'B', 'A', 'A'],
    'Feature3': [1, 1, 0, 0, 1],
})

y = pd.Series([1, 0, 1, 0, 1])

# Create a contingency table between each feature and the target variable
for feature in X.columns:
    contingency_table = pd.crosstab(X[feature], y)
    chi2, _, _, _ = chi2_contingency(contingency_table)
    print(f"Chi-square value for {feature}: {chi2}")
# Out:
# Chi-square value for Feature1: 1.7013888888888886
# Chi-square value for Feature2: 0.0
# Chi-square value for Feature3: 0.0

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Example data (replace this with your own data)
observed_data = np.array([[20, 30, 40], [10, 25, 35]])

# Initialize a list to store chi-square values for each feature
chi_square_values = []

# Compute chi-square statistic for each feature
for feature_data in observed_data:
    chi2, _, _, _ = chi2_contingency([feature_data])
    chi_square_values.append(chi2)

# Create a list of feature indices sorted by chi-square values (higher values first)
sorted_indices = np.argsort(chi_square_values)[::-1]

# Rank features based on chi-square values
ranked_features = [(index, chi_square_values[index]) for index in sorted_indices]

# Print the ranked features
print("Ranked features based on chi-square values:")
for rank, (feature_index, chi_square) in enumerate(ranked_features, start=1):
    print(f"Rank {rank}: Feature {feature_index + 1} (Chi-square: {chi_square:.2f})")
# Out:
# Ranked features based on chi-square values:
# Rank 1: Feature 2 (Chi-square: 0.00)
# Rank 2: Feature 1 (Chi-square: 0.00)

# %%
x=df.select_dtypes(include=['float64', 'int64'])
X=x.drop('MODELYEAR', axis=1)
X
# Out:
#       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0            2.0          4                   9.9                  6.7
# 1            2.4          4                  11.2                  7.7
# 2            1.5          4                   6.0                  5.8
# 3            3.5          6                  12.7                  9.1
# 4            3.5          6                  12.1                  8.7
# ...          ...        ...                   ...                  ...
# 1062         3.0          6                  13.4                  9.8
# 1063         3.2          6                  13.2                  9.5
# 1064         3.0          6                  13.4                  9.8
# 1065         3.2          6                  12.9                  9.3
# 1066         3.2          6                  14.9                 10.2
#
#       FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                      8.5                        33           196
# 1                      9.6                        29           221
# 2                      5.9                        48           136
# 3                     11.1                        25           255
# 4                     10.6                        27           244
# ...                    ...                       ...           ...
# 1062                  11.8                        24           271
# 1063                  11.5                        25           264
# 1064                  11.8                        24           271
# 1065                  11.3                        25           260
# 1066                  12.8                        22           294
#
# [1067 rows x 7 columns]

# %%
# chi-square feature selection
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2, f_regression
from numpy import array

y=X['CO2EMISSIONS'] # target column
x=X.drop('CO2EMISSIONS', axis=1)

select = SelectKBest(score_func=chi2, k=3)

z = select.fit_transform(x,y)

filter = select.get_support()

feat_labels=x.columns

features = array(feat_labels)
print("All features:")
print(features)

print("Selected best 3:")
print(features[filter])


#for i in range(len(select.scores_)):
#	print('Feature %d: %f' % (i, select.scores_[i]))
# Out:
# All features:
# ['ENGINESIZE' 'CYLINDERS' 'FUELCONSUMPTION_CITY' 'FUELCONSUMPTION_HWY'
#  'FUELCONSUMPTION_COMB' 'FUELCONSUMPTION_COMB_MPG']
# Selected best 3:
# ['FUELCONSUMPTION_CITY' 'FUELCONSUMPTION_COMB' 'FUELCONSUMPTION_COMB_MPG']

# %%
filter
# Out:
# array([False, False,  True, False,  True,  True])

# %%
x=df.select_dtypes(include=['float64', 'int64'])
X=x.drop('MODELYEAR', axis=1)
X
# Out:
#       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0            2.0          4                   9.9                  6.7
# 1            2.4          4                  11.2                  7.7
# 2            1.5          4                   6.0                  5.8
# 3            3.5          6                  12.7                  9.1
# 4            3.5          6                  12.1                  8.7
# ...          ...        ...                   ...                  ...
# 1062         3.0          6                  13.4                  9.8
# 1063         3.2          6                  13.2                  9.5
# 1064         3.0          6                  13.4                  9.8
# 1065         3.2          6                  12.9                  9.3
# 1066         3.2          6                  14.9                 10.2
#
#       FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                      8.5                        33           196
# 1                      9.6                        29           221
# 2                      5.9                        48           136
# 3                     11.1                        25           255
# 4                     10.6                        27           244
# ...                    ...                       ...           ...
# 1062                  11.8                        24           271
# 1063                  11.5                        25           264
# 1064                  11.8                        24           271
# 1065                  11.3                        25           260
# 1066                  12.8                        22           294
#
# [1067 rows x 7 columns]

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Sample data (replace with your own data)

y = X['CO2EMISSIONS'] # target column

X=X.drop('CO2EMISSIONS', axis=1)



# Create a contingency table between each feature and the target variable
for feature in X.columns:
    contingency_table = pd.crosstab(X[feature], y)
    chi2, _, _, _ = chi2_contingency(contingency_table)
    print(f"Chi-square value for {feature}: {chi2}")
# Out:
# Chi-square value for ENGINESIZE: 17239.7120131964
# Chi-square value for CYLINDERS: 3795.312717687078
# Chi-square value for FUELCONSUMPTION_CITY: 67468.01331387098
# Chi-square value for FUELCONSUMPTION_HWY: 45930.576699797144
# Chi-square value for FUELCONSUMPTION_COMB: 137369.680005069
# Chi-square value for FUELCONSUMPTION_COMB_MPG: 41085.271386961016

# %% [markdown]
# # Variance Threshold based feature extraction

# %%
from sklearn.feature_selection import VarianceThreshold
import numpy as np

# Create sample data
X = np.array([[0, 2, 0, 3],
              [0, 1, 4, 3],
              [0, 1, 1, 3]])

# Apply Variance Threshold
threshold = 0.1
selector = VarianceThreshold(threshold=threshold)
X_selected = selector.fit_transform(X)

print("Original features:", X.shape[1])
print("Selected features:", X_selected.shape[1])
# Out:
# Original features: 4
# Selected features: 2

# %% [markdown]
# # ANOVA (Analysis of Variance) feature selection

# %%
import pandas as pd
from scipy.stats import f_oneway

# Load dataset
data = pd.read_csv('dataset.csv')

# List of features
features = ['feature1', 'feature2', 'feature3']  # Replace with your actual feature column names

# Target column
target = 'target'  # Replace with your actual target column name

# Perform ANOVA for each feature
for feature in features:
    feature_groups = [data[data[feature] == level][target] for level in data[feature].unique()]
    F_value, p_value = f_oneway(*feature_groups)
    print("Feature:", feature)
    print("F-value:", F_value)
    print("p-value:", p_value)
